# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
df = pd.read_csv("../data/clean_dataset.csv")

df_ai = pd.read_json("../data/data.json")

# %%
x = df["rating"]

rating_counts = df["rating"].value_counts().sort_index()

rating_ia_rounded = df_ai["rating_ia"].round().astype(int)

rating_ia_counts = rating_ia_rounded.value_counts().sort_index()

labels = ["1 estrella", "2 estrellas", "3 estrellas", "4 estrellas", "5 estrellas"]

width = 0.35

# %%
fig, ax = plt.subplots(figsize=(8,5))

rating = ax.bar(x = rating_counts.index - witdh/2, height = rating_counts.values, tick_label=labels, label="Customer", width=width)

rating_ai = ax.bar(x = rating_ia_counts.index  + witdh/2, height = rating_ia_counts.values, tick_label = labels, label="AI", width=width)

plt.show()
